# %% [markdown]
# # Importing the requisite libraries and datasets:

# %% [markdown]
# # Attribute Information:
#
# Only 14 attributes used:
# 1. #3 (age)
# 2. #4 (sex)
# 3. #9 (cp)
# 4. #10 (trestbps)
# 5. #12 (chol)
# 6. #16 (fbs)
# 7. #19 (restecg)
# 8. #32 (thalach)
# 9. #38 (exang)
# 10. #40 (oldpeak)
# 11. #41 (slope)
# 12. #44 (ca)
# 13. #51 (thal)
# 14. #58 (num) (the predicted attribute)
#
#
# # Complete attribute documentation:
# 1. id: patient identification number
# 2. ccf: social security number (I replaced this with a dummy value of 0)
# 3. age: age in years
# 4. sex: sex (1 = male; 0 = female)
# 5. painloc: chest pain location (1 = substernal; 0 = otherwise)
# 6. painexer (1 = provoked by exertion; 0 = otherwise)
# 7. relrest (1 = relieved after rest; 0 = otherwise)
# 8. pncaden (sum of 5, 6, and 7)
# 9. cp: chest pain type
# -- Value 1: typical angina
# -- Value 2: atypical angina
# -- Value 3: non-anginal pain
# -- Value 4: asymptomatic
# 10. trestbps: resting blood pressure (in mm Hg on admission to the hospital)
# 11. htn
# 12. chol: serum cholestoral in mg/dl
# 13. smoke: I believe this is 1 = yes; 0 = no (is or is not a smoker)
# 14. cigs (cigarettes per day)
# 15. years (number of years as a smoker)
# 16. fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# 17. dm (1 = history of diabetes; 0 = no such history)
# 18. famhist: family history of coronary artery disease (1 = yes; 0 = no)
# 19. restecg: resting electrocardiographic results
# -- Value 0: normal
# -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
# 20. ekgmo (month of exercise ECG reading)
# 21. ekgday(day of exercise ECG reading)
# 22. ekgyr (year of exercise ECG reading)
# 23. dig (digitalis used furing exercise ECG: 1 = yes; 0 = no)
# 24. prop (Beta blocker used during exercise ECG: 1 = yes; 0 = no)
# 25. nitr (nitrates used during exercise ECG: 1 = yes; 0 = no)
# 26. pro (calcium channel blocker used during exercise ECG: 1 = yes; 0 = no)
# 27. diuretic (diuretic used used during exercise ECG: 1 = yes; 0 = no)
# 28. proto: exercise protocol
# - 1 = Bruce
# - 2 = Kottus
# - 3 = McHenry
# - 4 = fast Balke
# - 5 = Balke
# - 6 = Noughton
# - 7 = bike 150 kpa min/min (Not sure if "kpa min/min" is what was written!)
# - 8 = bike 125 kpa min/min
# - 9 = bike 100 kpa min/min
# - 10 = bike 75 kpa min/min
# - 11 = bike 50 kpa min/min
# - 12 = arm ergometer
# 29. thaldur: duration of exercise test in minutes
# 30. thaltime: time when ST measure depression was noted
# 31. met: mets achieved
# 32. thalach: maximum heart rate achieved
# 33. thalrest: resting heart rate
# 34. tpeakbps: peak exercise blood pressure (first of 2 parts)
# 35. tpeakbpd: peak exercise blood pressure (second of 2 parts)
# 36. dummy
# 37. trestbpd: resting blood pressure
# 38. exang: exercise induced angina (1 = yes; 0 = no)
# 39. xhypo: (1 = yes; 0 = no)
# 40. oldpeak = ST depression induced by exercise relative to rest
# 41. slope: the slope of the peak exercise ST segment
# -- Value 1: upsloping
# -- Value 2: flat
# -- Value 3: downsloping
# 42. rldv5: height at rest
# 43. rldv5e: height at peak exercise
# 44. ca: number of major vessels (0-3) colored by flourosopy
# 45. restckm: irrelevant
# 46. exerckm: irrelevant
# 47. restef: rest raidonuclid (sp?) ejection fraction
# 48. restwm: rest wall (sp?) motion abnormality
# - 0 = none
# - 1 = mild or moderate
# - 2 = moderate or severe
# - 3 = akinesis or dyskmem (sp?)
# 49. exeref: exercise radinalid (sp?) ejection fraction
# 50.  exerwm: exercise wall (sp?) motion
# 51.  thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
# 52.  thalsev: not used
# 53.  thalpul: not used
# 54.  earlobe: not used
# 55.  cmo: month of cardiac cath (sp?) (perhaps "call")
# 56.  cday: day of cardiac cath (sp?)
# 57.  cyr: year of cardiac cath (sp?)
# 58.  num: diagnosis of heart disease (angiographic disease status)
# -- Value 0: < 50% diameter narrowing
# -- Value 1: > 50% diameter narrowing
# (in any major vessel: attributes 59 through 68 are vessels)
# 59.  lmt
# 60.  ladprox
# 61.  laddist
# 62.  diag
# 63.  cxmain
# 64.  ramus
# 65.  om1
# 66.  om2
# 67.  rcaprox
# 68.  rcadist
# 69.  lvx1: not used
# 70.  lvx2: not used
# 71.  lvx3: not used
# 72.  lvx4: not used
# 73.  lvf: not used
# 74.  cathef: not used
# 75.  junk: not used
# 76.  name: last name of patient (I replaced this with the dummy string "name")

# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
# %pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
import pandas

from scipy.stats import randint

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score, f1_score

# %%
# %pip install plotnine
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached plotnine-0.12.1-py3-none-any.whl (1.3 MB)
# ...
#   Using cached statsmodels-0.14.0-cp310-cp310-win_amd64.whl (9.2 MB)
# ...
#   Using cached mizani-0.9.0-py3-none-any.whl (73 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ann_visualizer
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for ann_visualizer: filename=ann_visualizer-2.5-py3-none-any.whl size=4181 sha256=943323f2697a232d2c2479d7f0d947894713733a8da31fc1b2d0c22208b65a5b
#   Stored in directory: c:\users\buith\appdata\local\pip\cache\wheels\80\94\c7\ea1fe2ebea70fbbfb9425d284cc27f170ab6fe59ef3c31b56f
# Successfully built ann_visualizer
# ...

# %%
# %pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ydata_profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ydata_profiling-4.1.2-py2.py3-none-any.whl (345 kB)
# ...
#   Using cached numpy-1.23.5-cp310-cp310-win_amd64.whl (14.6 MB)
# ...
#   Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
# ...
#   Using cached phik-0.12.3-cp310-cp310-win_amd64.whl (663 kB)
# ...
#   Using cached statsmodels-0.13.5-cp310-cp310-win_amd64.whl (9.1 MB)
# ...
#   Using cached matplotlib-3.6.3-cp310-cp310-win_amd64.whl (7.2 MB)
# ...
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# ...
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#   Using cached scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
# ...
#   Using cached multimethod-1.9.1-py3-none-any.whl (10 kB)
# ...
#   Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
# ...

# %%
# import ydata_profiling as pandas_profiling

# import matplotlib.pyplot
# import altair
# from plotnine import  *

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
column_titles = "id, ccf, age, sex, painloc, painexer, relrest, pncaden, cp, trestbps, htn, chol, smoke, cigs, years, fbs, dm, famhist, restecg, ekgmo, ekgday, ekgyr, dig, prop, nitr, pro, diuretic, proto, thaldur, thaltime, met, thalach, thalrest, tpeakbps, tpeakbpd, dummy, trestbpd, exang, xhypo, oldpeak, slope, rldv5, rldv5e, ca, restckm, exerckm, restef, restwm, exeref, exerwm, thal, thalsev, thalpul, earlobe, cmo, cday, cyr, num, lmt, ladprox, laddist, diag, cxmain, ramus, om1, om2, rcaprox, rcadist, lvx1, lvx2, lvx3, lvx4, lvf, cathef, junk"
important_titles = "age, sex, cp, trestbps, chol, fbs, restecg, prop, nitr, pro, diuretic, thalach, thalrest, tpeakbps, tpeakbpd, trestbpd, exang, oldpeak, slope, thal, num"
categorical_titles = "sex, cp, fbs, dm, famhist, restecg, prop, nitr, pro, diuretic, exang, slope, ca, thal, num"
numerical_titles = "age, trestbps, chol, cigs, years, thalach, thalrest, tpeakbps, tpeakbpd, trestbpd, oldpeak"

reccomended_columns = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "num"]
tuning_columns = ["cp", "thalach", "exang", "chol", "oldpeak", "age", "slope", "num"]

all_columns = column_titles.split(sep=", ")
important_columns = important_titles.split(sep=", ")
categorical_columns = categorical_titles.split(sep=", ")
numerical_columns = numerical_titles.split(sep=", ")

print("Total number of columns in dataset : ", len(all_columns))
print("Number of columns deemed important : ", len(important_columns))
print("Number of columns reccomended by other research papers : ", len(reccomended_columns))
# Out:
# Total number of columns in dataset :  75
# Number of columns deemed important :  21
# Number of columns reccomended by other research papers :  14

# %%
def getDataFrame(filePath):
  file = open(filePath)
  data = []
  lines = file.read()
  lines = lines.replace("\n", " ", -1).split(sep="name")
  for line in lines:
    line = line.strip()
    row = line.split(sep=" ")
    data.append(row)
  dataFrame = pandas.DataFrame(data, columns=all_columns)
  targetField = dataFrame.pop("num")
  dataFrame.insert(74, "num", targetField)
  return dataFrame

# %%
# Import the datasets:

dataFrame_1 = getDataFrame("switzerland.data")
print(dataFrame_1.shape)

dataFrame_2 = getDataFrame("hungarian.data")
print(dataFrame_2.shape)


dataFrame_3 = getDataFrame("long-beach-va.data")
print(dataFrame_3.shape)


dataFrame_4 = getDataFrame("cleveland.data")
print(dataFrame_4.shape)
# Out:
# (124, 75)
# (295, 75)
# (201, 75)
# (283, 75)

# %%
# Provide some basic descriptive statistic for each dataset:

print("Data Frame 1:")
print(dataFrame_1.info)
print(dataFrame_1.describe())

print("\nData Frame 2:")
print(dataFrame_2.info)
print(dataFrame_2.describe())

print("\nData Frame 3:")
print(dataFrame_3.info)
print(dataFrame_3.describe())

print("\nData Frame 4:")
print(dataFrame_4.info)
print(dataFrame_4.describe())
# Out:
# Data Frame 1:
# <bound method DataFrame.info of        id   ccf   age   sex painloc painexer relrest pncaden    cp trestbps
# 0    3001     0    65     1       1        1       1      -9     4      115  \
# 1    3002     0    32     1       0        0       0      -9     1       95
# 2    3003     0    61     1       1        1       1      -9     4      105
# 3    3004     0    50     1       1        1       1      -9     4      145
# 4    3005     0    57     1       1        1       1      -9     4      110
# ..    ...   ...   ...   ...     ...      ...     ...     ...   ...      ...
# 119  4071     0    56     1       1        1       1      -9     4      125
# 120  4072     0    56     1       0        1       1      -9     3      125
# 121  4073     0    54     1       1        1       1      -9     4      130
# 122  4074     0    66     0       1        1       1      -9     4      155
# 123        None  None  None    None     None    None    None  None     None
#
# ...

# %% [markdown]
# # Cleaning the dataset:

# %%
# Check the count of existing null value fields and disply those columns:

print("\nDataFrame 1:")
print(dataFrame_1[dataFrame_1.isnull().any(axis=1)])

print("\nDataFrame 2:")
print(dataFrame_2[dataFrame_2.isnull().any(axis=1)])

print("\nDataFrame 3:")
print(dataFrame_3[dataFrame_3.isnull().any(axis=1)])

print("\nDataFrame 4:")
print(dataFrame_4[dataFrame_4.isnull().any(axis=1)])
# Out:
# DataFrame 1:
#     id   ccf   age   sex painloc painexer relrest pncaden    cp trestbps  ...
# 123     None  None  None    None     None    None    None  None     None  ...  \
#
#     rcaprox rcadist  lvx1  lvx2  lvx3  lvx4   lvf cathef  junk   num
# 123    None    None  None  None  None  None  None   None  None  None
#
# [1 rows x 75 columns]
#
# DataFrame 2:
#     id   ccf   age   sex painloc painexer relrest pncaden    cp trestbps  ...
# 294     None  None  None    None     None    None    None  None     None  ...  \
#
#     rcaprox rcadist  lvx1  lvx2  lvx3  lvx4   lvf cathef  junk   num
# 294    None    None  None  None  None  None  None   None  None  None
#
# [1 rows x 75 columns]
#
# DataFrame 3:
#     id   ccf   age   sex painloc painexer relrest pncaden    cp trestbps  ...
# 200     None  None  None    None     None    None    None  None     None  ...  \
#
#     rcaprox rcadist  lvx1  lvx2  lvx3  lvx4   lvf cathef  junk   num
# ...

# %%
# Drop any rows containing null values:

dataFrame_1.dropna(how="any", inplace=True)
dataFrame_2.dropna(how="any", inplace=True)
dataFrame_3.dropna(how="any", inplace=True)
dataFrame_4.dropna(how="any", inplace=True)

# %%
# Check any columns still containing null after cleaning:

print("\nDataFrame 1:")
print(dataFrame_1[dataFrame_1.isnull().any(axis=1)])

print("\nDataFrame 2:")
print(dataFrame_2[dataFrame_2.isnull().any(axis=1)])

print("\nDataFrame 3:")
print(dataFrame_3[dataFrame_3.isnull().any(axis=1)])

print("\nDataFrame 4:")
print(dataFrame_4[dataFrame_4.isnull().any(axis=1)])
# Out:
# DataFrame 1:
# Empty DataFrame
# Columns: [id, ccf, age, sex, painloc, painexer, relrest, pncaden, cp, trestbps, htn, chol, smoke, cigs, years, fbs, dm, famhist, restecg, ekgmo, ekgday, ekgyr, dig, prop, nitr, pro, diuretic, proto, thaldur, thaltime, met, thalach, thalrest, tpeakbps, tpeakbpd, dummy, trestbpd, exang, xhypo, oldpeak, slope, rldv5, rldv5e, ca, restckm, exerckm, restef, restwm, exeref, exerwm, thal, thalsev, thalpul, earlobe, cmo, cday, cyr, lmt, ladprox, laddist, diag, cxmain, ramus, om1, om2, rcaprox, rcadist, lvx1, lvx2, lvx3, lvx4, lvf, cathef, junk, num]
# Index: []
#
# [0 rows x 75 columns]
#
# DataFrame 2:
# Empty DataFrame
# ...

# %%
# This function replaces dummy values or error values with appropriate values that can actually be used by the regression models going forward.
# For example, we are replacing the '-9's in the dataFrames with an appropriate '0' value in the columns for cigarettes and years smoked.

def replaceValues(dataFrame):
  dataFrame["dm"] = dataFrame["dm"].replace("-9", "0")
  dataFrame["cigs"] = dataFrame["cigs"].replace("-9", "0")
  dataFrame["years"] = dataFrame["years"].replace("-9", "0")

  dataFrame["ca"] = dataFrame["ca"].replace("-9", "0")
  dataFrame["thal"] = dataFrame["thal"].replace("-9", "3")

  dataFrame["nitr"] = dataFrame["nitr"].replace("-9", "0")
  dataFrame["prop"] = dataFrame["prop"].replace("-9", "0")
  dataFrame["pro"] = dataFrame["pro"].replace("-9", "0")
  dataFrame["diuretic"] = dataFrame["diuretic"].replace("-9", "0")
  dataFrame["restecg"] = dataFrame["restecg"].replace("-9", "0")

  dataFrame["trestbps"] = dataFrame["trestbps"].replace("-9", "0")
  dataFrame["chol"] = dataFrame["chol"].replace("-9", "0")
  dataFrame["fbs"] = dataFrame["fbs"].replace("-9", "0")
  dataFrame["famhist"] = dataFrame["famhist"].replace("-9", "0")
  dataFrame["thalach"] = dataFrame["thalach"].replace("-9", "0")
  dataFrame["thalrest"] = dataFrame["thalrest"].replace("-9", "0")

  dataFrame["tpeakbps"] = dataFrame["tpeakbps"].replace("-9", "0")
  dataFrame["tpeakbpd"] = dataFrame["tpeakbpd"].replace("-9", "0")
  dataFrame["trestbpd"] = dataFrame["trestbpd"].replace("-9", "0")

  dataFrame["exang"] = dataFrame["exang"].replace("-9", "0")
  dataFrame["oldpeak"] = dataFrame["oldpeak"].replace("-9", "0")
  dataFrame["slope"] = dataFrame["slope"].replace("-9", "0")

  #dataFrame["num"] = dataFrame["num"].replace(["1", "2", "3", "4"], "1")

  #dataFrame[['num','sex','cp','ca']] = dataFrame[['num','sex','cp','ca']].astype("category")
  #dataFrame[['age','thalach']]=dataFrame[['age','thalach']].apply(pandas.to_numeric)

  for col in dataFrame.columns:
    dataFrame[col] = numpy.float64(dataFrame[col])

  return dataFrame

# %%
dataFrame_1 = replaceValues(dataFrame_1)
dataFrame_2 = replaceValues(dataFrame_2)
dataFrame_3 = replaceValues(dataFrame_3)
dataFrame_4 = replaceValues(dataFrame_4)

# %%
dataFrame = pandas.concat([dataFrame_1, dataFrame_2, dataFrame_3, dataFrame_4])
dataFrame_smaller = dataFrame[tuning_columns]
dataFrame_bigger = dataFrame[important_columns]
dataFrame.shape
# Out:
# (899, 75)

# %%
pip install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# ...
#   Using cached ydata_profiling-4.1.2-py2.py3-none-any.whl (345 kB)
# ...
#   Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
# ...
#   Using cached statsmodels-0.13.5-cp310-cp310-win_amd64.whl (9.1 MB)
# ...
#   Using cached scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
# ...
#   Using cached phik-0.12.3-cp310-cp310-win_amd64.whl (663 kB)
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#   Using cached multimethod-1.9.1-py3-none-any.whl (10 kB)
# ...
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# ...
#   Using cached matplotlib-3.6.3-cp310-cp310-win_amd64.whl (7.2 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.0
#     Uninstalling pandas-2.0.0:
#       Successfully uninstalled pandas-2.0.0
# ...

# %% [markdown]
# # Descriptive Statistics and Exploration:

# %%
# pandas_profiling.ProfileReport(dataFrame_1[reccomended_columns])

# %%
# pandas_profiling.ProfileReport(dataFrame_2[reccomended_columns])

# %%
# pandas_profiling.ProfileReport(dataFrame_3[reccomended_columns])

# %%
# pandas_profiling.ProfileReport(dataFrame_4[reccomended_columns])

# %% [markdown]
# # Visulisation of the attributes in the dataset using the plotnine package:

# %%
# # Distribution Graph of age by Heart Disease
# (
#   ggplot(dataFrame_4)
#   +aes(x="age", fill=("num")) +
#   geom_density(alpha = 0.8)+
#   ggtitle("Age by Heart Disease") +
#   xlab("Age")+
#   scale_fill_discrete(name = "Heart Disease", labels = ["Yes", "No"])
# )

# %%
# # Distribution Graph of Age by Sex
# (
#   ggplot(dataFrame_4)
#   +aes(x="age", fill=("sex")) +
#   geom_density(alpha = 0.8)+
#   ggtitle("Age by Sex") +
#   xlab("Age")+
#   scale_fill_discrete(name = "Sex", labels = ["Male", "Female"])
# )

# %%
# # Distribution Graph of Max Heart Rate by Heart Disease
# (
#   ggplot(dataFrame_4)
#   +aes(x="thalach", fill=("num")) +
#   geom_density(alpha = 0.8)+
#   ggtitle("Max Heart Rate by Heart Disease") +
#   xlab("Max Heart Rate")+
#   scale_fill_discrete(name = "Heart Disease", labels = ["Yes", "No"])
# )

# %%
# # Distribution Graph of Max Heart Rate by Sex
# (
#   ggplot(dataFrame_4)
#   +aes(x="thalach", fill=("sex")) +
#   geom_density(alpha = 0.8)+
#   ggtitle("Max Heart Rate by Sex") +
#   xlab("Max Heart Rate")+
#   scale_fill_discrete(name = "Sex", labels = ["Male", "Female"])
# )

# %%
# # Bar Chart of Heart Disease Condition segmented by Chest Pain Type
# (
#   ggplot(dataFrame_4)
#   +aes( x="num", fill=("cp")) +
#   geom_bar()
#   +ggtitle("Chest Pain Type by Heart Disease") 
#   +scale_fill_discrete(name="Chest Pain Type",labels=["Value 1: typical angina", "Value 2: atypical angina", "Value 3: non-anginal pain", "Value 4: asymptomatic"])
#   +xlab("Heart Disease Condition") +
#   ylab("Count") 
# )

# %%
# # Bar Chart of Heart Disease Condition Segmented by Number of Major Vessels
# (
#   ggplot(dataFrame_4)
#   +aes( x="num", fill=("ca")) +
#   geom_bar()
#   +ggtitle("Number of Major Vessels by Heart Disease") 
#   +scale_fill_discrete(name="Number of major vessels")
#   +xlab("Heart Disease Condition") +
#   ylab("Count") 
# )

# %%
# pandas_profiling.ProfileReport(dataFrame)

# %%
# %pip install matplotplib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotplib (from versions: none)
# ERROR: No matching distribution found for matplotplib

# %% [markdown]
# # Classification:

# %% [markdown]
# ### Logistic Regression.

# %%
temp_dataFrame = dataFrame_bigger.copy()
temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")

X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
logisticRegression = LogisticRegression(solver="newton-cholesky", class_weight="balanced")
logisticRegression.fit(X_train, y_train)
y_train_preds = logisticRegression.predict(X_train)
y_test_preds = logisticRegression.predict(X_test)

print("\nTraining Data :")
print("Accuracy Score : ", accuracy_score(y_train, y_train_preds))
print("F1 Score : ", f1_score(y_train, y_train_preds, average='weighted'))

print("\nTesting Data :")
print("Accuracy Score : ", accuracy_score(y_test, y_test_preds))
print("F1 Score : ", f1_score(y_test, y_test_preds, average='weighted'))

print("\nConfusion Matrix for Training :\n", confusion_matrix(y_train, y_train_preds, labels=logisticRegression.classes_))
print("\nConfusion Matrix for Testing :\n", confusion_matrix(y_test, y_test_preds, labels=logisticRegression.classes_))
# Out:
# Training Data :
# Accuracy Score :  0.8166877370417194
# F1 Score :  0.8168683760248248
#
# Testing Data :
# Accuracy Score :  0.8611111111111112
# F1 Score :  0.8615081771540232
#
# Confusion Matrix for Training :
#  [[289  68]
#  [ 77 357]]
#
# Confusion Matrix for Testing :
#  [[41  6]
#  [ 9 52]]

# %%
cross_val_score(logisticRegression, X_train, y_train, cv=10, scoring='accuracy')
# Out:
# array([0.825     , 0.84810127, 0.73417722, 0.78481013, 0.81012658,
#        0.75949367, 0.83544304, 0.78481013, 0.83544304, 0.74683544])

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import ConfusionMatrixDisplay

# %%
import matplotlib.pyplot as plt

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_train, y_train_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_test, y_test_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
import pandas as pd
# Get the feature importances from the Random Forest model
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': logisticRegression.coef_[0]
}).sort_values('importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_importance)), feature_importance['importance'])
plt.xticks(range(len(feature_importance)), feature_importance['feature'], rotation='vertical')
plt.xlabel("Features")
plt.ylabel("Coefficient Value")
plt.title("Logistic Regression Coefficients")
plt.show()

print(feature_importance)
# Out:
#      feature  importance
# 1        sex    1.249886
# 16     exang    0.859720
# 2         cp    0.774961
# 17   oldpeak    0.437941
# 5        fbs    0.384317
# 18     slope    0.310314
# 9        pro    0.280407
# 19      thal    0.243899
# 7       prop    0.209993
# 8       nitr    0.131020
# 3   trestbps    0.015957
# 0        age    0.012057
# 12  thalrest    0.004931
# 14  tpeakbpd    0.003426
# 13  tpeakbps   -0.001104
# 4       chol   -0.002325
# 11   thalach   -0.014564
# 15  trestbpd   -0.023739
# 6    restecg   -0.054936
# 10  diuretic   -0.333724

# %% [markdown]
# ### Support Vector Classifier.

# %%
temp_dataFrame = dataFrame_bigger.copy()
temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")
X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
svc = SVC(class_weight="balanced",
          kernel="linear",
          C=1.0,
          gamma=0.001)
svc.fit(X_train, y_train)

y_train_preds = svc.predict(X_train)
y_test_preds = svc.predict(X_test)

print("\n Training Data :")
print("Accuracy Score : ", accuracy_score(y_train, y_train_preds))
print("F1 Score : ", f1_score(y_train, y_train_preds, average='weighted'))

print("\n Testing Data :")
print("Accuracy Score : ", accuracy_score(y_test, y_test_preds))
print("F1 Score : ", f1_score(y_test, y_test_preds, average='weighted'))

print("\nConfusion Matrix for Training :\n", confusion_matrix(y_train, y_train_preds, labels=svc.classes_))
print("\nConfusion Matrix for Testing :\n", confusion_matrix(y_test, y_test_preds, labels=svc.classes_))
# Out:
#  Training Data :
# Accuracy Score :  0.8192161820480405
# F1 Score :  0.8192383460411756
#
#  Testing Data :
# Accuracy Score :  0.8796296296296297
# F1 Score :  0.8797657596700659
#
# Confusion Matrix for Training :
#  [[286  71]
#  [ 72 362]]
#
# Confusion Matrix for Testing :
#  [[41  6]
#  [ 7 54]]

# %%
cross_val_score(svc, X_train, y_train, cv=10, scoring='accuracy')
# Out:
# array([0.825     , 0.88607595, 0.73417722, 0.78481013, 0.83544304,
#        0.7721519 , 0.82278481, 0.79746835, 0.82278481, 0.72151899])

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_train, y_train_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_test, y_test_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

feature_coefficients = pd.DataFrame({
    'feature': X_train.columns,
    'coefficient': svc.coef_[0]
}).sort_values('coefficient', ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_coefficients)), feature_coefficients['coefficient'])
plt.xticks(range(len(feature_coefficients)), feature_coefficients['feature'], rotation='vertical')
plt.xlabel("Features")
plt.ylabel("Coefficient Value")
plt.title("SVM Coefficients")
plt.show()

print(feature_coefficients)
# Out:
#      feature  coefficient
# 1        sex     0.790482
# 16     exang     0.696209
# 2         cp     0.691461
# 17   oldpeak     0.306810
# 8       nitr     0.216333
# 19      thal     0.215061
# 5        fbs     0.183324
# 9        pro     0.167625
# 18     slope     0.141142
# 7       prop     0.091637
# 0        age     0.011758
# 3   trestbps     0.006318
# 14  tpeakbpd     0.003448
# 12  thalrest     0.003378
# 13  tpeakbps    -0.000979
# 4       chol    -0.001966
# 11   thalach    -0.008526
# 15  trestbpd    -0.014128
# 6    restecg    -0.061739
# 10  diuretic    -0.235596

# %% [markdown]
# ### Decision Tree.

# %%
temp_dataFrame = dataFrame_bigger.copy()
temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")
X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
tree = DecisionTreeClassifier(class_weight="balanced",
                              max_depth=4,
                              min_samples_leaf=20
                              )
tree.fit(X_train, y_train)

y_train_preds = tree.predict(X_train)
y_test_preds = tree.predict(X_test)

print("\n Training Data :")
print("Accuracy Score : ", accuracy_score(y_train, y_train_preds))
print("F1 Score : ", f1_score(y_train, y_train_preds, average='weighted'))

print("\n Testing Data :")
print("Accuracy Score : ", accuracy_score(y_test, y_test_preds))
print("F1 Score : ", f1_score(y_test, y_test_preds, average='weighted'))

print("\nConfusion Matrix for Training :\n", confusion_matrix(y_train, y_train_preds, labels=tree.classes_))
print("\nConfusion Matrix for Testing :\n", confusion_matrix(y_test, y_test_preds, labels=tree.classes_))
# Out:
#  Training Data :
# Accuracy Score :  0.7989886219974716
# F1 Score :  0.7993895053667668
#
#  Testing Data :
# Accuracy Score :  0.8240740740740741
# F1 Score :  0.8248162497409162
#
# Confusion Matrix for Training :
#  [[289  68]
#  [ 91 343]]
#
# Confusion Matrix for Testing :
#  [[41  6]
#  [13 48]]

# %%
cross_val_score(tree, X_train, y_train, cv=10, scoring='accuracy')
# Out:
# array([0.7375    , 0.7721519 , 0.74683544, 0.74683544, 0.67088608,
#        0.73417722, 0.74683544, 0.75949367, 0.78481013, 0.72151899])

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_train, y_train_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_test, y_test_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

feature_importances = pd.DataFrame({
    'feature': X_train.columns,
    'importance': tree.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_importances)), feature_importances['importance'])
plt.xticks(range(len(feature_importances)), feature_importances['feature'], rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importances')
plt.show()

# %%
# Get the feature importances from the Random Forest model
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': tree.coef_[0]
}).sort_values('importance', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Get the feature importances from the Random Forest model
# ----> 2 feature_importance = pd.DataFrame({
#       3     'feature': X_train.columns,
#       4     'importance': tree.coef_[0]
#       5 }).sort_values('importance', ascending=False)
#
# NameError: name 'pd' is not defined

# %%
print(feature_importances)

# %% [markdown]
# ### Random Forest Algorithm

# %%
temp_dataFrame = dataFrame_bigger.copy()
temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")
X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
estimator = RandomForestClassifier(class_weight="balanced",
                                   n_estimators=50,
                                   max_depth=8,
                                   min_samples_split=100
                                   )
estimator.fit(X_train, y_train)

y_train_preds = estimator.predict(X_train)
y_test_preds = estimator.predict(X_test)

print("\nTraining Data :")
print("Accuracy Score : ", accuracy_score(y_train, y_train_preds))
print("F1 Score : ", f1_score(y_train, y_train_preds, average='weighted'))

print("\nTesting Data :")
print("Accuracy Score : ", accuracy_score(y_test, y_test_preds))
print("F1 Score : ", f1_score(y_test, y_test_preds, average='weighted'))

print("\nConfusion Matrix for Training :\n", confusion_matrix(y_train, y_train_preds, labels=estimator.classes_))
print("\nConfusion Matrix for Testing :\n", confusion_matrix(y_test, y_test_preds, labels=estimator.classes_))
# Out:
# Training Data :
# Accuracy Score :  0.8305941845764855
# F1 Score :  0.8301244187031718
#
# Testing Data :
# Accuracy Score :  0.8425925925925926
# F1 Score :  0.842770608799317
#
# Confusion Matrix for Training :
#  [[281  76]
#  [ 58 376]]
#
# Confusion Matrix for Testing :
#  [[39  8]
#  [ 9 52]]

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_train, y_train_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_test, y_test_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
feature_importance = pandas.DataFrame(
    {
        'feature' : X_train.columns,
        'importance' : estimator.feature_importances_
    }
).sort_values('importance', ascending=False)
print(feature_importance)
# Out:
#      feature  importance
# 2         cp    0.281905
# 16     exang    0.145114
# 11   thalach    0.100846
# 18     slope    0.094947
# 17   oldpeak    0.080607
# 1        sex    0.058470
# 0        age    0.054789
# 19      thal    0.047518
# 4       chol    0.046637
# 12  thalrest    0.027237
# 8       nitr    0.013968
# 3   trestbps    0.012343
# 13  tpeakbps    0.009767
# 15  trestbpd    0.009024
# 14  tpeakbpd    0.007930
# 5        fbs    0.004096
# 9        pro    0.002579
# 6    restecg    0.001265
# 7       prop    0.000849
# 10  diuretic    0.000110

# %%
# Sort the DataFrame by 'importance' column in ascending order
feature_importance_sorted = feature_importance.sort_values('importance', ascending=True)

# Create the horizontal bar chart
plt.barh(feature_importance_sorted['feature'], feature_importance_sorted['importance'])

# Add labels and title
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')

# Show the chart
plt.show()

# %%
cross_val_score(estimator, X_train, y_train, cv=10, scoring='accuracy')
# Out:
# array([0.75      , 0.83544304, 0.75949367, 0.82278481, 0.79746835,
#        0.75949367, 0.83544304, 0.74683544, 0.86075949, 0.78481013])

# %% [markdown]
# ### Extra Random Tree

# %%
temp_dataFrame = dataFrame_bigger.copy()
temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")
X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
random_ranges = {
    'n_estimators': randint(50, 250),
    'min_samples_split': randint(150, 250),
    'max_leaf_nodes': randint(4, 64),
    'max_depth': randint(1,16)
}

classifier = ExtraTreesClassifier(random_state=8, max_features="log2", class_weight="balanced")

randomSearcher = RandomizedSearchCV(classifier, random_ranges, random_state=8, scoring='neg_root_mean_squared_error', cv=10, verbose=1)
randomSearcher.fit(X_train, y_train)

print(randomSearcher.best_params_)

estimator = randomSearcher.best_estimator_

y_train_preds = estimator.predict(X_train)
y_test_preds = estimator.predict(X_test)

print("\nTraining Data :")
print("Accuracy Score : ", accuracy_score(y_train, y_train_preds))
print("F1 Score : ", f1_score(y_train, y_train_preds, average='weighted'))

print("\nTesting Data :")
print("Accuracy Score : ", accuracy_score(y_test, y_test_preds))
print("F1 Score : ", f1_score(y_test, y_test_preds, average='weighted'))

print("\nConfusion Matrix for Training :\n", confusion_matrix(y_train, y_train_preds, labels=estimator.classes_))
print("\nConfusion Matrix for Testing :\n", confusion_matrix(y_test, y_test_preds, labels=estimator.classes_))
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'max_depth': 10, 'max_leaf_nodes': 55, 'min_samples_split': 218, 'n_estimators': 231}
#
# Training Data :
# Accuracy Score :  0.797724399494311
# F1 Score :  0.7979042231937877
#
# Testing Data :
# Accuracy Score :  0.8240740740740741
# F1 Score :  0.8247575469797691
#
# Confusion Matrix for Training :
#  [[281  76]
#  [ 84 350]]
#
# Confusion Matrix for Testing :
#  [[40  7]
#  [12 49]]

# %%
feature_importance = pandas.DataFrame(
    {
        'feature' : X_train.columns,
        'importance' : estimator.feature_importances_
    }
).sort_values('importance', ascending=False)
print(feature_importance)
# Out:
#      feature  importance
# 16     exang    0.291094
# 2         cp    0.214412
# 1        sex    0.121757
# 18     slope    0.076777
# 19      thal    0.058206
# 11   thalach    0.057473
# 4       chol    0.030144
# 17   oldpeak    0.029201
# 8       nitr    0.028996
# 0        age    0.025971
# 9        pro    0.022339
# 13  tpeakbps    0.008698
# 12  thalrest    0.008279
# 15  trestbpd    0.006033
# 5        fbs    0.005478
# 14  tpeakbpd    0.004727
# 7       prop    0.004271
# 3   trestbps    0.003995
# 6    restecg    0.001773
# 10  diuretic    0.000375

# %%
# Sort the DataFrame by 'importance' column in ascending order
feature_importance_sorted = feature_importance.sort_values('importance', ascending=True)

# Create the horizontal bar chart
plt.barh(feature_importance_sorted['feature'], feature_importance_sorted['importance'])

# Add labels and title
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')

# Show the chart
plt.show()

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_train, y_train_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_test, y_test_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %% [markdown]
# # Neural Networks:

# %% [markdown]
# ### Classification

# %%
temp_dataFrame = dataFrame_bigger.copy()
temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")

X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
hidden_layers = [512]
hidden_activation = 'relu'
solver_algo = 'lbfgs'
lr_init = 0.0025
lr = 'adaptive'
batch_size = 32
epochs = 200

# %%
neuralNetwork = MLPClassifier(
    hidden_layer_sizes=hidden_layers, 
    batch_size=batch_size, 
    activation=hidden_activation, 
    solver=solver_algo, 
    learning_rate_init=lr_init, 
    learning_rate = lr,
    max_iter=epochs,
    random_state=1
).fit(X_train, y_train)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
y_train_preds = neuralNetwork.predict(X_train)
y_test_preds = neuralNetwork.predict(X_test)

print("\nTraining Data :")
print("Accuracy Score : ", accuracy_score(y_train, y_train_preds))
print("F1 Score : ", f1_score(y_train, y_train_preds, average='weighted'))

print("\nTesting Data :")
print("Accuracy Score : ", accuracy_score(y_test, y_test_preds))
print("F1 Score : ", f1_score(y_test, y_test_preds, average='weighted'))

print("\nConfusion Matrix for Training :\n", confusion_matrix(y_train, y_train_preds, labels=neuralNetwork.classes_))
print("\nConfusion Matrix for Testing :\n", confusion_matrix(y_test, y_test_preds, labels=neuralNetwork.classes_))
# Out:
# Training Data :
# Accuracy Score :  0.8293299620733249
# F1 Score :  0.8289483707491411
#
# Testing Data :
# Accuracy Score :  0.8425925925925926
# F1 Score :  0.842386183718468
#
# Confusion Matrix for Training :
#  [[282  75]
#  [ 60 374]]
#
# Confusion Matrix for Testing :
#  [[38  9]
#  [ 8 53]]

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_train, y_train_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
# Obtain the confusion matrix
cm = confusion_matrix(y_test, y_test_preds)

# Uncomment the following line to just print the matrix to the standard output
# print(cm)

cm_display = ConfusionMatrixDisplay(cm) # Initiate a ConfusionMatrixDisplay object
cm_display.plot() # Plot the object
plt.show() # Display the plot

# %%
X_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'prop',
#        'nitr', 'pro', 'diuretic', 'thalach', 'thalrest', 'tpeakbps',
#        'tpeakbpd', 'trestbpd', 'exang', 'oldpeak', 'slope', 'thal'],
#       dtype='object')

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Calculate the probabilities for the positive class
y_train_probs = neuralNetwork.predict_proba(X_train)[:, 1]
y_test_probs = neuralNetwork.predict_proba(X_test)[:, 1]

# Calculate the false positive rate and true positive rate for the training data
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_probs)
auc_train = roc_auc_score(y_train, y_train_probs)

# Calculate the false positive rate and true positive rate for the test data
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_probs)
auc_test = roc_auc_score(y_test, y_test_probs)

# Plot the ROC curve for training and test data
plt.plot(fpr_train, tpr_train, label=f"Train ROC Curve (AUC = {auc_train:.2f})")
plt.plot(fpr_test, tpr_test, label=f"Test ROC Curve (AUC = {auc_test:.2f})")
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# The AUC ranges from 0 to 1, where:
#
# AUC = 1: Perfect classifier. The model has a perfect ability to distinguish between the positive and negative classes. It correctly ranks all the positive instances higher than the negative instances.
# AUC > 0.5 and AUC < 1: Better than random classifier. The model has some ability to differentiate between the positive and negative classes, and its performance is better than a random guess. The higher the AUC, the better the model performance.
# AUC = 0.5: Random classifier. The model performs no better than a random guess. It has no ability to distinguish between the positive and negative classes.
# AUC < 0.5: Inverted classifier. The model performs worse than a random guess. It tends to rank the negative instances higher than the positive instances.
# Therefore, when evaluating a classification model using the ROC curve and AUC, a value closer to 1 indicates a stronger model performance in correctly classifying instances. However, it's important to consider other evaluation metrics and domain-specific requirements to get a comprehensive understanding of the model's performance.

# %% [markdown]
# Train ROC Curve (AUC=0.91): The AUC value of 0.91 suggests that the model performs well in differentiating between the positive and negative classes in the training set. A higher AUC indicates a better performance, and a value of 0.91 indicates a good model performance.
# For the test data:
#
# Test ROC Curve (AUC=0.88): The AUC value of 0.88 indicates that the model performs well in distinguishing between the positive and negative classes in the test set. Though the AUC is slightly lower than the training AUC, it still suggests a good model performance.
#
# Overall, both the training and test ROC curves indicate that your MLP classifier model has a relatively strong ability to classify instances correctly.

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Compute precision, recall, and threshold for training data
train_precision, train_recall, train_thresholds = precision_recall_curve(y_train, y_train_probs)

# Compute precision, recall, and threshold for testing data
test_precision, test_recall, test_thresholds = precision_recall_curve(y_test, y_test_probs)

# Plot precision-recall curve for training data
plt.figure(figsize=(8, 6))
plt.plot(train_recall, train_precision, label='Training Data')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve - Training Data')
plt.legend(loc='lower left')
plt.show()

# Plot precision-recall curve for testing data
plt.figure(figsize=(8, 6))
plt.plot(test_recall, test_precision, label='Testing Data')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve - Testing Data')
plt.legend(loc='lower left')
plt.show()

# %%
#Neural Network Architecture:
import matplotlib.pyplot as plt

layer_sizes = neuralNetwork.hidden_layer_sizes
layer_sizes = [X_train.shape[1]] + list(layer_sizes) + [2]  # Include input and output layer sizes

plt.figure(figsize=(10, 5))
plt.title("Neural Network Architecture")
plt.xlabel("Layers")
plt.ylabel("Number of Neurons")

plt.bar(range(len(layer_sizes)), layer_sizes)
plt.show()

# %%
#Weight Visualizations:
weights = neuralNetwork.coefs_

plt.figure(figsize=(10, 5))
plt.title("Weight Visualization")
plt.xlabel("Neuron Index")
plt.ylabel("Weight Value")

for layer in weights:
    for neuron_weights in layer.T:
        plt.plot(neuron_weights)
plt.show()

# %%
print("The number of layers in the neural network model: "+ str(len(weights)))
# Out:
# The number of layers in the neural network model: 2

# %% [markdown]
# ***Each line in the plot represents the weights associated with a specific neuron in the neural network.***
#
# ***The x-coordinate of each point on the line corresponds to the index of the weight within the neuron.***
#
# ***The y-coordinate of each point represents the value of the weight.***

# %% [markdown]
# **Prominent line**: The line that ranges from 0 to 500 represents a specific neuron in the neural network. The fact that this line extends to a higher weight value suggests that this neuron's connections carry more significant importance or have a stronger influence on the network's output compared to other neurons.

# %% [markdown]
# **Stacked and shrink lines**: The other lines that appear stacked and shrink to around 0-10 indicate a set of neurons whose weights are relatively lower. This pattern might suggest that these neurons have weaker connections or contribute less to the overall decision-making process of the neural network.

# %%
# Stastical analysis
layer_stats = []
for i, layer_weights in enumerate(weights):
    neuron_stats = []
    print(f"Layer {i+1}:")
    for j, neuron_weights in enumerate(layer_weights.T):
        mean_weight = np.mean(neuron_weights)
        std_weight = np.std(neuron_weights)
        min_weight = np.min(neuron_weights)
        max_weight = np.max(neuron_weights)
        neuron_stats.append((mean_weight, std_weight, min_weight, max_weight))
        print(f"Neuron {j+1}: Mean={mean_weight:.2f}, Std={std_weight:.2f}, Min={min_weight:.2f}, Max={max_weight:.2f}")
    layer_stats.append(neuron_stats)
# Out:
# Layer 1:
# Neuron 1: Mean=-0.00, Std=0.06, Min=-0.09, Max=0.10
# Neuron 2: Mean=-0.00, Std=0.07, Min=-0.14, Max=0.10
# Neuron 3: Mean=0.03, Std=0.07, Min=-0.08, Max=0.13
# Neuron 4: Mean=0.01, Std=0.06, Min=-0.11, Max=0.09
# Neuron 5: Mean=-0.00, Std=0.07, Min=-0.09, Max=0.10
# Neuron 6: Mean=-0.02, Std=0.07, Min=-0.10, Max=0.10
# Neuron 7: Mean=-0.00, Std=0.06, Min=-0.13, Max=0.11
# Neuron 8: Mean=-0.03, Std=0.06, Min=-0.10, Max=0.11
# Neuron 9: Mean=0.01, Std=0.05, Min=-0.13, Max=0.12
# Neuron 10: Mean=-0.00, Std=0.05, Min=-0.10, Max=0.09
# Neuron 11: Mean=0.01, Std=0.06, Min=-0.09, Max=0.10
# Neuron 12: Mean=-0.01, Std=0.07, Min=-0.10, Max=0.10
# Neuron 13: Mean=-0.03, Std=0.06, Min=-0.10, Max=0.09
# Neuron 14: Mean=-0.00, Std=0.07, Min=-0.10, Max=0.10
# Neuron 15: Mean=0.00, Std=0.06, Min=-0.10, Max=0.09
# Neuron 16: Mean=-0.01, Std=0.07, Min=-0.13, Max=0.07
# Neuron 17: Mean=-0.03, Std=0.06, Min=-0.10, Max=0.09
# Neuron 18: Mean=-0.00, Std=0.06, Min=-0.10, Max=0.09
# ...

# %%
# Plotting feature importance for each layer
plt.figure(figsize=(12, 8))  # Adjust the figure size as per your preference
plt.title('Feature Importance by Layer')

bar_width = 0.2  # Width of each bar
layer_distance = 0.4  # Distance between layers

for layer_index, importances in enumerate(layer_importances):
    sorted_idx = importances.importances_mean.argsort()
    layer_offset = layer_index * layer_distance
    
    plt.barh(np.arange(X_train.shape[1]) + layer_offset, importances.importances_mean[sorted_idx], height=bar_width, label='Layer {}'.format(layer_index + 1))
    
    # Add numeric values to the bars and print feature importance
    for i, value in enumerate(importances.importances_mean[sorted_idx]):
        feature_name = feature_names[sorted_idx[i]]
        print(f"Feature importance of Layer {layer_index + 1}: - {feature_name}: {value:.3f}")
        plt.text(value, i + layer_offset, f'{value:.3f}', va='center')
    
plt.yticks(np.arange(X_train.shape[1]), np.array(feature_names)[sorted_idx])
plt.xlabel('Importance')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Feature importance of Layer 1: - nitr: -0.005
# Feature importance of Layer 1: - restecg: -0.005
# Feature importance of Layer 1: - exang: -0.001
# Feature importance of Layer 1: - fbs: -0.001
# Feature importance of Layer 1: - pro: -0.000
# Feature importance of Layer 1: - prop: -0.000
# Feature importance of Layer 1: - diuretic: -0.000
# Feature importance of Layer 1: - slope: 0.001
# Feature importance of Layer 1: - sex: 0.001
# Feature importance of Layer 1: - age: 0.001
# Feature importance of Layer 1: - oldpeak: 0.016
# Feature importance of Layer 1: - trestbps: 0.019
# Feature importance of Layer 1: - thalrest: 0.025
# Feature importance of Layer 1: - tpeakbpd: 0.029
# Feature importance of Layer 1: - cp: 0.031
# Feature importance of Layer 1: - thal: 0.033
# Feature importance of Layer 1: - trestbpd: 0.035
# Feature importance of Layer 1: - tpeakbps: 0.039
# Feature importance of Layer 1: - thalach: 0.051
# Feature importance of Layer 1: - chol: 0.064
# ...

# %% [markdown]
# - Layer 1 consists of 111 neurons.
# - Each neuron has statistics calculated for its weights, including mean, standard deviation (std), minimum (min), and maximum (max) values.
# - The mean values for most neurons are close to zero, indicating that the weights are balanced around zero.
# - The standard deviations (std) provide a measure of the spread or variability of the weights for each neuron. Most neurons have a std between 0.05 and 0.07, indicating moderate variability.
# - The minimum and maximum values for each neuron provide insights into the range of weights assigned to that particular neuron. The range varies between neurons, but generally, the weights fall within the range of -0.15 to 0.15.
# - Some neurons have larger ranges (e.g., Neuron 107 with a range of -0.11 to 0.09) or higher standard deviations (e.g., Neuron 59 with a std of 0.05) compared to others. These neurons may have more influence or variability in the network's computations.

# %% [markdown]
# **exang, restecg and nitr have negative feature importances so they have a detrimental effect on the model's predictive performance. It means that as the value of that features , the model's predictions become less accurate or less reliable**

# %% [markdown]
# Layer 1 assigns positive importance to four features: trestbpd, tpeakbps, thalach, and chol. These features are considered important and contribute positively to the model's predictions.
#
# Layer 2 assigns both positive and negative importance values to various features. Features with positive importance contribute positively, while features with negative importance have a detrimental effect on the model's performance. It's worth noting that some features have negligible importance with values close to zero.

# %% [markdown]
# Positive values indicate that the corresponding feature positively contributes to the model's predictive performance, while negative values suggest a detrimental effect

# %%
len(layer_weights)
# Out:
# 6

# %%
# Calculate feature importance for each layer
layer_importance = []
for i, layer_weights in enumerate(neuralNetwork.coefs_):
    layer_importance.append(np.mean(np.abs(layer_weights), axis=0))

# Plot feature importance for each layer
fig, ax = plt.subplots(figsize=(10, 6))
for i, importance in enumerate(layer_importance, start=1):
    ax.bar(range(1, len(importance) + 1), importance, label='Layer {}'.format(i))

ax.set_xlabel('Feature Index')
ax.set_ylabel('Feature Importance')
ax.set_title('Feature Importance of Each Layer')
ax.legend()
plt.show()

# %%
# Calculate feature importance for each layer
layer_importance = []
for i, layer_weights in enumerate(neuralNetwork.coefs_):
    layer_importance.append(np.mean(np.abs(layer_weights), axis=0))

# Plot feature importance for each layer
fig, ax = plt.subplots(figsize=(10, 6))
for i, importance in enumerate(layer_importance, start=1):
    ax.bar(range(1, len(importance) + 1), importance, label='Layer {}'.format(i))

ax.set_xlabel('Feature Index')
ax.set_ylabel('Feature Importance')
ax.set_title('Feature Importance of Each Layer')
ax.legend()
plt.show()

# %%
# Print feature importance for each layer
for layer_index, importances in enumerate(layer_importances):
    sorted_idx = importances.importances_mean.argsort()
    
    for i, value in enumerate(importances.importances_mean[sorted_idx]):
        feature_name = feature_names[sorted_idx[i]]
        print(f"Feature importance of Layer {layer_index + 1}: - {feature_name}: {value:.3f}")
# Out:
# Feature importance of Layer 1: - nitr: -0.005
# Feature importance of Layer 1: - restecg: -0.005
# Feature importance of Layer 1: - exang: -0.001
# Feature importance of Layer 1: - fbs: -0.001
# Feature importance of Layer 1: - pro: -0.000
# Feature importance of Layer 1: - prop: -0.000
# Feature importance of Layer 1: - diuretic: -0.000
# Feature importance of Layer 1: - slope: 0.001
# Feature importance of Layer 1: - sex: 0.001
# Feature importance of Layer 1: - age: 0.001
# Feature importance of Layer 1: - oldpeak: 0.016
# Feature importance of Layer 1: - trestbps: 0.019
# Feature importance of Layer 1: - thalrest: 0.025
# Feature importance of Layer 1: - tpeakbpd: 0.029
# Feature importance of Layer 1: - cp: 0.031
# Feature importance of Layer 1: - thal: 0.033
# Feature importance of Layer 1: - trestbpd: 0.035
# Feature importance of Layer 1: - tpeakbps: 0.039
# Feature importance of Layer 1: - thalach: 0.051
# Feature importance of Layer 1: - chol: 0.064
# ...

# %%
from tabulate import tabulate

# Create a list to store the table data
table_data = []

# Determine the number of layers
num_layers = min(len(layer_importances), 2)  # Consider up to 2 layers

# Collect feature names and importances for each layer
for layer_index in range(num_layers):
    importances = layer_importances[layer_index]
    sorted_idx = importances.importances_mean.argsort()

    for i, value in enumerate(importances.importances_mean[sorted_idx]):
        feature_name = feature_names[sorted_idx[i]]
        table_data.append([f"Layer {layer_index + 1}", feature_name, value])

# Sort the table data by layer and importance value in descending order
sorted_table_data = sorted(table_data, key=lambda x: (x[0], x[2]), reverse=True)

# Generate the table using tabulate
table = tabulate(sorted_table_data, headers=["Layer", "Feature", "Importance"], tablefmt="grid")

# Print the table
print(table)
# Out:
# +---------+-----------+--------------+
# | Layer   | Feature   |   Importance |
# +=========+===========+==============+
# | Layer 2 | chol      |  0.0635904   |
# +---------+-----------+--------------+
# | Layer 2 | thalach   |  0.0509482   |
# +---------+-----------+--------------+
# | Layer 2 | tpeakbps  |  0.0393173   |
# +---------+-----------+--------------+
# | Layer 2 | trestbpd  |  0.0351454   |
# +---------+-----------+--------------+
# | Layer 2 | thal      |  0.0326169   |
# +---------+-----------+--------------+
# | Layer 2 | cp        |  0.0310999   |
# +---------+-----------+--------------+
# | Layer 2 | tpeakbpd  |  0.02933     |
# +---------+-----------+--------------+
# | Layer 2 | thalrest  |  0.025158    |
# +---------+-----------+--------------+
# | Layer 2 | trestbps  |  0.0189633   |
# +---------+-----------+--------------+
# | Layer 2 | oldpeak   |  0.0164349   |
# +---------+-----------+--------------+
# | Layer 2 | age       |  0.000884956 |
# ...

# %% [markdown]
# Analysis of the feature importance results:
#
# ***For Layer 1:***
#
# + The most important feature is "chol" (serum cholestoral in mg/dl) with an importance value of 0.064.
# + Other important features in Layer 1 include:
# "thalach" (maximum heart rate achieved) with an importance value of 0.051.
# "tpeakbps" (peak exercise blood pressure, first of 2 parts) with an importance value of 0.039.
# "trestbpd" (resting blood pressure) with an importance value of 0.035.
# "cp" (chest pain type) with an importance value of 0.031.
# "thal" (3 = normal, 6 = fixed defect, 7 = reversible defect) with an importance value of 0.033.
#
# ***For Layer 2:***
#
# + The most important feature is again "chol" with an importance value of 0.064, indicating its consistent significance across layers.
# + The remaining features in Layer 2 have relatively lower importance values ranging from -0.005 to 0.033.
# + Features such as "tpeakbpd" (peak exercise blood pressure, second of 2 parts) and "oldpeak" (ST depression induced by exercise relative to rest) have importance values of 0.029 and 0.016 respectively, which are notable but relatively lower compared to "chol".
#
#
# Overall, the analysis suggests that "chol" is consistently identified as the most important feature across both layers of the neural network. Other features like "thalach", "tpeakbps", "trestbpd", "cp", and "thal" also contribute significantly to the prediction of heart disease. These findings align with the domain knowledge of cardiovascular health, where factors like cholesterol levels, heart rate, and blood pressure are known to be relevant indicators of heart disease.

# %% [markdown]
# ### Regression

# %%
temp_dataFrame = dataFrame_bigger.copy()
#temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")

X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
hidden_layers = [128]
hidden_activation = 'relu'
solver_algo = 'adam'
lr_init = 0.001
lr = 'constant'
batch_size = 32
epochs = 5

# %%
neuralNetwork = MLPRegressor(
    hidden_layer_sizes=hidden_layers, 
    batch_size=batch_size, 
    activation=hidden_activation, 
    solver=solver_algo, 
    learning_rate_init=lr_init, 
    learning_rate = lr,
    max_iter=epochs,
    random_state=1
).fit(X_train, y_train)
# Out:
# C:\Users\buith\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5) reached and the optimization hasn't converged yet.

# %%
y_train_preds = neuralNetwork.predict(X_train)
y_test_preds = neuralNetwork.predict(X_test)

print(mean_squared_error(y_train, y_train_preds))
print(mean_absolute_error(y_train, y_train_preds))

print(mean_squared_error(y_test, y_test_preds))
print(mean_absolute_error(y_test, y_test_preds))
# Out:
# 1.5014565400532571
# 0.9631860837070207
# 1.7037597070854318
# 0.9846019936949406

# %% [markdown]
# # Regression:

# %%
temp_dataFrame = dataFrame_bigger.copy()
#temp_dataFrame["num"].replace([1.0, 2.0, 3.0, 4.0], 1, inplace=True)

y = temp_dataFrame.pop("num")

X_train, X_test, y_train, y_test = train_test_split(temp_dataFrame, y, test_size=0.12, random_state=42)

# %%
poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(X_train)
poly.fit_transform(X_test)

poly.fit(X_train_poly, y_train)

linReg = LinearRegression()
linReg.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_train_preds = linReg.predict(poly.fit_transform(X_train))
y_test_preds = linReg.predict(poly.fit_transform(X_test))

print(mean_squared_error(y_train, y_train_preds))
print(mean_absolute_error(y_train, y_train_preds))

print(mean_squared_error(y_test, y_test_preds))
print(mean_absolute_error(y_test, y_test_preds))
# Out:
# 1.2107298706714646
# 0.8626747713076933
# 3.3893186067216896
# 1.433150933848487
